# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithranair/DANN/blob/main/DANN_OfficeHome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/Transfer-Learning-Library-master.zip
# Out:
# Archive:  /content/Transfer-Learning-Library-master.zip
# 4df94ed9d13b6777506118d84c4aecfd1ef878b6
#    creating: Transfer-Learning-Library-master/
#    creating: Transfer-Learning-Library-master/.github/
#    creating: Transfer-Learning-Library-master/.github/ISSUE_TEMPLATE/
#   inflating: Transfer-Learning-Library-master/.github/ISSUE_TEMPLATE/bug_report.md
#   inflating: Transfer-Learning-Library-master/.github/ISSUE_TEMPLATE/custom.md
#   inflating: Transfer-Learning-Library-master/.github/ISSUE_TEMPLATE/feature_request.md
#   inflating: Transfer-Learning-Library-master/.gitignore
#   inflating: Transfer-Learning-Library-master/CONTRIBUTING.md
#   inflating: Transfer-Learning-Library-master/LICENSE
#   inflating: Transfer-Learning-Library-master/README.md
#   inflating: Transfer-Learning-Library-master/Tllib.png
#    creating: Transfer-Learning-Library-master/docs/
#   inflating: Transfer-Learning-Library-master/docs/Makefile
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/Transfer-Learning-Library-master/examples/domain_adaptation/image_classification
# Out:
# /content/Transfer-Learning-Library-master/examples/domain_adaptation/image_classification

# %%
# !python dann.py data/officeHome -d OfficeHome -s Cl -t Pr -a resnet50 --epochs 20 --seed 1 --log logs/dann/Office31_A2W
# Out:
# Namespace(arch='resnet50', batch_size=32, bottleneck_dim=256, data='OfficeHome', epochs=20, iters_per_epoch=1000, log='logs/dann/Office31_A2W', lr=0.01, lr_decay=0.75, lr_gamma=0.001, momentum=0.9, no_hflip=False, no_pool=False, norm_mean=(0.485, 0.456, 0.406), norm_std=(0.229, 0.224, 0.225), per_class_eval=False, phase='train', print_freq=100, ratio=[0.75, 1.3333333333333333], resize_size=224, root='data/officeHome', scale=[0.08, 1.0], scratch=False, seed=1, source=['Cl'], target=['Pr'], trade_off=1.0, train_resizing='default', val_resizing='default', weight_decay=0.001, workers=2)
# dann.py:40: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# train_transform:  Compose(
#     Compose(
#     ResizeImage(size=(256, 256))
# ...

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 548 kB 23.1 MB/s
# ...
#      |████████████████████████████████| 163 kB 65.3 MB/s
# ...

# %%
# !pip install prettytable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python dann.py data/officeHome -d OfficeHome -s Ar -t Rw -a resnet50 --epochs 20 --seed 1 --log logs/dann/Office31_A2W --phase test
